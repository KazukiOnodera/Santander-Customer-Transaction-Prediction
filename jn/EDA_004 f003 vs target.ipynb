# %%
import numpy as np
import pandas as pd
import os, gc
from glob import glob
from tqdm import tqdm

import sys
sys.path.append(f'/home/{os.environ.get("USER")}/PythonLibrary')

import EDA

# %%
tr = pd.read_pickle('../data/train_f003.pkl').iloc[:, :200]
te = pd.read_pickle('../data/test_f003.pkl').iloc[:, :200]

tr['target'] = pd.read_pickle('../data/target.pkl')['target']

# %%
tr.head()
# Out:
#    f003_var_0  f003_var_1  f003_var_2  f003_var_3  f003_var_4  f003_var_5  \
# 0           8           3           4           6           4           2
# 1           3           3           2           3           3           1
# 2           6           1           6           6           6           2
# 3           3           8           7           9           8           3
# 4           8           5           4           5          10           1
#
#    f003_var_6  f003_var_7  f003_var_8  f003_var_9  ...  f003_var_191  \
# 0          12           3           5           6  ...             8
# 1          14           5           4          10  ...             5
# 2           3           4           1           8  ...             5
# 3          10           5           2           9  ...             3
# 4           7           2           1          11  ...             8
#
#    f003_var_192  f003_var_193  f003_var_194  f003_var_195  f003_var_196  \
# ...

# %%
te.head()
# Out:
#    f003_var_0  f003_var_1  f003_var_2  f003_var_3  f003_var_4  f003_var_5  \
# 0           4           8           7           8           7           2
# 1           1           3           2           5           7           1
# 2           3           5           2           1           4           4
# 3           2           3           3           4           4           4
# 4           3           1           3           5          11           1
#
#    f003_var_6  f003_var_7  f003_var_8  f003_var_9  ...  f003_var_190  \
# 0          16           4           4           8  ...             3
# 1          16           2           2          11  ...             5
# 2          12           3           3           9  ...             2
# 3          15           4           2           8  ...             6
# 4           2           6           3          10  ...             5
#
#    f003_var_191  f003_var_192  f003_var_193  f003_var_194  f003_var_195  \
# ...

# %%
EDA.continuous_vs_target(tr, te.columns, target='target', kind='hist', normalize=True, bins=100, alpha=0.8,
                        test=te)
# Out:
# f003_var_0
# f003_var_1
# f003_var_2
# f003_var_3
# f003_var_4
# f003_var_5
# f003_var_6
# f003_var_7
# f003_var_8
# f003_var_9
# f003_var_10
# f003_var_11
# f003_var_12
# f003_var_13
# f003_var_14
# f003_var_15
# f003_var_16
# f003_var_17
# f003_var_18
# f003_var_19
# f003_var_20
# f003_var_21
# f003_var_22
# f003_var_23
# f003_var_24
# f003_var_25
# f003_var_26
# f003_var_27
# f003_var_28
# f003_var_29
# f003_var_30
# f003_var_31
# f003_var_32
# f003_var_33
# f003_var_34
# f003_var_35
# f003_var_36
# f003_var_37
# f003_var_38
# f003_var_39
# f003_var_40
# f003_var_41
# f003_var_42
# f003_var_43
# f003_var_44
# f003_var_45
# f003_var_46
# f003_var_47
# f003_var_48
# f003_var_49
# f003_var_50
# f003_var_51
# f003_var_52
# f003_var_53
# f003_var_54
# f003_var_55
# f003_var_56
# f003_var_57
# f003_var_58
# f003_var_59
# f003_var_60
# f003_var_61
# f003_var_62
# f003_var_63
# f003_var_64
# f003_var_65
# f003_var_66
# f003_var_67
# f003_var_68
# f003_var_69
# f003_var_70
# f003_var_71
# ...

# %%
tr.var_113.plot(kind='hist', bins=200, density=True, alpha=0.8)

# %%
te.var_113.plot(kind='hist', bins=200, density=True, alpha=0.8)
